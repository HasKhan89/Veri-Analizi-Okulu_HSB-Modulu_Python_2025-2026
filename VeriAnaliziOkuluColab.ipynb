# %% [markdown]
# <a href="https://colab.research.google.com/github/HasKhan89/Veri-Analizi-Okulu_HSB-Modulu_Python_2025-2026/blob/main/VeriAnaliziOkuluColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
isim = input("Adınızı giriniz: ")
print(f"Merhaba {isim} ")
# Out:
# Adınızı giriniz: Hasan
# Merhaba Hasan

# %%
dogumYılı = int(input("Doğum yılınızı giriniz: "))
yas = 2026 - dogumYılı
print(f" {yas} - Yaşındasınız " )
# Out:
# Doğum yılınızı giriniz: 1989
#  37 - Yaşındasınız
